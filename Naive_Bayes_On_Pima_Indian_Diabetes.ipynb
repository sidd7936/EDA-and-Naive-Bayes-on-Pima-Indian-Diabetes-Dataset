# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('pima_indin_diabetes.csv')

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
sns.pairplot(df, hue = 'Outcome')

# %%
sns.heatmap(df.corr(), cmap='YlOrRd', annot=True, fmt = '.1f')

# %%
df.hist(figsize=(16, 16))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000141BB4E69C8>,
# ...
#       dtype=object)

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
fig, ax1 = plt.subplots(1, 2, figsize = (5,5))

sns.countplot(df['Outcome'], ax = ax1[0])
labels = 'Diabetic', 'Healthy'
df.Outcome.value_counts().plot.pie(labels=labels, autopct='%1.1f%%',shadow=True, startangle=90, ax=ax1[1])

# %%
fig, ax1 = plt.subplots(2, 2, figsize = (4, 4))
sns.boxplot(df['Glucose'], ax = ax1[0,0])
sns.boxplot(df['BloodPressure'], ax=ax1[0,1])
sns.boxplot(df['BloodPressure'], ax = ax1[1,0])
sns.boxplot(df['Insulin'], ax = ax1[1,1])

# %%
fig, ax1 = plt.subplots(2, 3, figsize = (18, 8))
sns.regplot(x = 'Age', y = 'BloodPressure', data=df, ax=ax1[0][0])
sns.regplot(x = 'Age', y = 'Insulin', data=df, ax=ax1[0][1])
sns.regplot(x = 'Age', y = 'Pregnancies', data=df, ax=ax1[0][2])
sns.regplot(x = 'Age', y = 'BMI', data=df, ax=ax1[1][2])
sns.regplot(x = 'Age', y = 'SkinThickness', data=df, ax=ax1[1][0])
sns.regplot(x = 'Age', y = 'Glucose', data=df, ax=ax1[1][1])

# %%
fig, ax2 = plt.subplots(2, 2, figsize = (9, 6))

sns.violinplot(x = 'Outcome', y = 'BloodPressure', data = df, ax = ax2[0][0])
sns.violinplot(x='Outcome', y='Insulin', data=df, ax=ax2[0][1])

sns.stripplot(x = 'Outcome', y = 'BMI', data=df, ax=ax2[1][0])
sns.swarmplot(x = 'Outcome', y = 'Pregnancies', data=df, ax=ax2[1][1])

# %%
fig, ax3 = plt.subplots(3, 2, figsize = (9, 8))

sns.barplot(x = 'Outcome', y = 'BloodPressure', data=df, ax=ax3[0][0])
sns.barplot(x='Outcome', y='Pregnancies', data=df, ax=ax3[0][1])
sns.barplot(x='Outcome', y='Glucose', data=df, ax=ax3[1][0])
sns.barplot(x='Outcome', y='BMI', data=df, ax=ax3[1][1])
sns.barplot(x='Outcome', y='SkinThickness', data=df, ax=ax3[2][0])
sns.barplot(x='Outcome', y='Insulin', data=df, ax=ax3[2][1])

# %%
sns.jointplot(x='Age', y='BloodPressure', kind='hex', data=df)
sns.jointplot(x='Glucose', y='BloodPressure', kind='hex', data=df)
sns.jointplot(x='Age', y='BMI', kind='hex', data=df)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# %%
X = df[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]
y = df.Outcome

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
model = GaussianNB()
fittedmodel = model.fit(X_train, y_train)
pred = fittedmodel.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
confusion_matrix = confusion_matrix(pred, y_test)
accuracy_score = accuracy_score(pred,y_test)

# %%
confusion_matrix
# Out:
# array([[125,  34],
#        [ 26,  46]], dtype=int64)

# %%
accuracy_score
# Out:
# 0.7402597402597403
